# %%
from pathlib import Path

# %%
raw_dir = Path("../data/raw")
json_files = sorted(raw_dir.glob("*.json"))

# %%
import json

all_games = []
files_processed = 0

for file_path in json_files:
    with file_path.open("r", encoding="utf-8") as f:
        data = json.load(f)

    results = data.get("results", [])

    # opcional: validar tipo
    if not isinstance(results, list):
        continue

    all_games.extend(results)
    files_processed += 1

    print(f"{file_path.name} -> {len(results)} juegos")

print(f"Archivos procesados: {files_processed}")
print(f"Total juegos acumulados: {len(all_games)}")

# %%
print(all_games[1])
# Out:
# {'slug': 'stalker-2', 'name': 'S.T.A.L.K.E.R. 2: Heart of Chornobyl', 'playtime': 7, 'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}, {'platform': {'id': 186, 'name': 'Xbox Series S/X', 'slug': 'xbox-series-x'}}], 'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}}, {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}}, {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}, {'store': {'id': 11, 'name': 'Epic Games', 'slug': 'epic-games'}}], 'released': '2024-11-20', 'tba': False, 'background_image': 'https://media.rawg.io/media/games/3e8/3e81585ecda204d4f4b80a041b069adb.jpg', 'rating': 3.79, 'rating_top': 5, 'ratings': [{'id': 5, 'title': 'exceptional', 'count': 137, 'percent': 42.55}, {'id': 4, 'title': 'recommended', 'count': 91, 'percent': 28.26}, {'id': 1, 'title': 'skip', 'count': 55, 'percent': 17.08}, {'id': 3, 'title': 'meh', 'count': 39, 'percent': 12.11}], 'ratings_count': 311, 'reviews_text_count': 8, 'added': 2194, 'added_by_status': {'yet': 341, 'owned': 544, 'beaten': 124, 'toplay': 1072, 'dropped': 68, 'playing': 45}, 'metacritic': None, 'suggestions_count': 498, 'updated': '2026-04-09T11:30:16', 'id': 58386, 'score': None, 'clip': None, 'tags': [{'id': 31, 'name': 'Singleplayer', 'slug': 'singleplayer', 'language': 'eng', 'games_count': 250826, 'image_background': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg'}, {'id': 42396, 'name': 'Для одного игрока', 'slug': 'dlia-odnogo-igroka', 'language': 'rus', 'games_count': 70694, 'image_background': 'https://media.rawg.io/media/games/b8c/b8c243eaa0fbac8115e0cdccac3f91dc.jpg'}, {'id': 42417, 'name': 'Экшен', 'slug': 'ekshen', 'language': 'rus', 'games_count': 50552, 'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'}, {'id': 40847, 'name': 'Steam Achievements', 'slug': 'steam-achievements', 'language': 'eng', 'games_count': 51709, 'image_background': 'https://media.rawg.io/media/games/b45/b45575f34285f2c4479c9a5f719d972e.jpg'}, {'id': 40849, 'name': 'Steam Cloud', 'slug': 'steam-cloud', 'language': 'eng', 'games_count': 25733, 'image_background': 'https://media.rawg.io/media/games/198/1988a337305e008b41d7f536ce9b73f6.jpg'}, {'id': 13, 'name': 'Atmospheric', 'slug': 'atmospheric', 'language': 'eng', 'games_count': 39707, 'image_background': 'https://media.rawg.io/media/games/562/562553814dd54e001a541e4ee83a591c.jpg'}, {'id': 42394, 'name': 'Глубокий сюжет', 'slug': 'glubokii-siuzhet', 'language': 'rus', 'games_count': 18115, 'image_background': 'https://media.rawg.io/media/games/310/3106b0e012271c5ffb16497b070be739.jpg'}, {'id': 24, 'name': 'RPG', 'slug': 'rpg', 'language': 'eng', 'games_count': 26624, 'image_background': 'https://media.rawg.io/media/games/26d/26d4437715bee60138dab4a7c8c59c92.jpg'}, {'id': 42412, 'name': 'Ролевая игра', 'slug': 'rolevaia-igra', 'language': 'rus', 'games_count': 23018, 'image_background': 'https://media.rawg.io/media/games/157/15742f2f67eacff546738e1ab5c19d20.jpg'}, {'id': 118, 'name': 'Story Rich', 'slug': 'story-rich', 'language': 'eng', 'games_count': 27258, 'image_background': 'https://media.rawg.io/media/games/960/960b601d9541cec776c5fa42a00bf6c4.jpg'}, {'id': 42442, 'name': 'Открытый мир', 'slug': 'otkrytyi-mir', 'language': 'rus', 'games_count': 7451, 'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'}, {'id': 36, 'name': 'Open World', 'slug': 'open-world', 'language': 'eng', 'games_count': 9265, 'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'}, {'id': 42428, 'name': 'Шутер', 'slug': 'shuter', 'language': 'rus', 'games_count': 11966, 'image_background': 'https://media.rawg.io/media/games/960/960b601d9541cec776c5fa42a00bf6c4.jpg'}, {'id': 42429, 'name': 'От первого лица', 'slug': 'ot-pervogo-litsa', 'language': 'rus', 'games_count': 16470, 'image_background': 'https://media.rawg.io/media/games/6c5/6c55e22185876626881b76c119 ...

# %%
genres_dict = {}

for game in all_games:
    for genre in game.get("genres", []):
        genre_id = genre.get("id")
        genre_name = genre.get("name")
    genres_dict[genre_id] = genre_name

# %%
print(len(genres_dict))
print(list(genres_dict.items())[:10])
# Out:
# 15
# [(4, 'Action'), (5, 'RPG'), (14, 'Simulation'), (51, 'Indie'), (3, 'Adventure'), (7, 'Puzzle'), (15, 'Sports'), (6, 'Fighting'), (83, 'Platformer'), (59, 'Massively Multiplayer')]

# %%
genres_data = [
    {"genre_id": g, "name": n}
    for g, n in genres_dict.items()
]

# %%
import pandas as pd
genres_df = pd.DataFrame(genres_data)

# %%
genres_df["genre_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
genres_df.isnull().sum()
# Out:
# genre_id    0
# name        0
# dtype: int64

# %%
genres_df.columns
# Out:
# Index(['genre_id', 'name'], dtype='str')
