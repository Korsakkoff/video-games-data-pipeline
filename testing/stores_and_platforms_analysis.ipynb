# %%
#ANALISIS DE PLATAFORMAS Y STORES


from get_rawg_platforms_df import fetch_platforms_df
import pandas as pd

pd.set_option("display.max_rows", None)
#from get_rawg_stores_df import fetch_stores_df

import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("RAWG_API_KEY")

platforms_df = fetch_platforms_df(API_KEY)
#stores_df = fetch_stores_df(API_KEY)

platforms_df = platforms_df.sort_values(by="games_count", ascending=False)
#stores_df.head()
# Out:
#     platform_id       platform_name       platform_slug  games_count  \
# 0             4                  PC                  pc       560716
# 50          171                 Web                 web       260067
# 11            5               macOS               macos       108040
# 12            6               Linux               linux        80386
# 6             3                 iOS                 ios        77443
# 7            21             Android             android        52528
# 3            18       PlayStation 4        playstation4         6988
# 5             7     Nintendo Switch     nintendo-switch         5768
# 2             1            Xbox One            xbox-one         5739
# 15           16       PlayStation 3        playstation3         3203
# 16           15       PlayStation 2        playstation2         2869
# 13           14            Xbox 360             xbox360         2829
# 9             9         Nintendo DS         nintendo-ds         2501
# ...

# %%
import pandas as pd

pd.set_option("display.max_rows", None)
from get_rawg_stores_df import fetch_stores_df

import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("RAWG_API_KEY")


stores_df = fetch_stores_df(API_KEY)

stores_df = stores_df.sort_values(by="games_count", ascending=False)

stores_df
# Out:
#    store_id         store_name         store_slug  games_count  \
# 8         9            itch.io               itch       654200
# 0         1              Steam              steam       123332
# 3         4          App Store     apple-appstore        75590
# 7         8        Google Play        google-play        17126
# 5         6     Nintendo Store           nintendo         9151
# 1         3  PlayStation Store  playstation-store         8076
# 4         5                GOG                gog         7244
# 2         2         Xbox Store         xbox-store         4938
# 6         7     Xbox 360 Store            xbox360         1915
# 9        11         Epic Games         epic-games         1451
#
#                    domain                                   image_background
# 8                 itch.io  https://media.rawg.io/media/games/e63/e635b8c7...
# 0  store.steampowered.com  https://media.rawg.io/media/games/120/1201a40e...
# ...
